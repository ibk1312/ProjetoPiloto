# %% [markdown]
# <a href="https://colab.research.google.com/github/ibk1312/ProjetoPiloto/blob/main/ProjetoPiloto_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: inclusão das referencias para chamar funções da bibliotecas

import pandas as pd
#import

# %%
def consulta_bc(codigo_bcb):
  url ='http://api.bcb.gov.br/dados/serie/bcdata.sgs.{}/dados?formato=json'.format(codigo_bcb)
  df = pd.read_json(url)
  df['data'] = pd.to_datetime(df['data'], dayfirst=True)
  df.set_index('data', inplace=True)
  return df

# IPCA = 433
# PTC - MPME - Demanda esperada = 21382
# PTC - MPME - Demanda observada = 21383

#var_ipca = consulta_bc(21382)
#var_ipca.plot()

var_MPME_esperado = consulta_bc(21382)
var_MPME_observado = consulta_bc(21383)

fig, ax = plt.subplots()
ax.plot(var_MPME_esperado)
ax.plot(var_MPME_observado);
